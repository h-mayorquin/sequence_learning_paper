# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Preamble" data-toc-modified-id="Preamble-0"><span class="toc-item-num">0&nbsp;&nbsp;</span>Preamble</a></span><ul class="toc-item"><li><span><a href="#Graphical-parameters" data-toc-modified-id="Graphical-parameters-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Graphical parameters</a></span></li><li><span><a href="#Functions" data-toc-modified-id="Functions-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span>Functions</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Number-of-iterations" data-toc-modified-id="Number-of-iterations-0.2.0.1"><span class="toc-item-num">0.2.0.1&nbsp;&nbsp;</span>Number of iterations</a></span></li><li><span><a href="#Sigma-sweep" data-toc-modified-id="Sigma-sweep-0.2.0.2"><span class="toc-item-num">0.2.0.2&nbsp;&nbsp;</span>Sigma sweep</a></span></li><li><span><a href="#Plot-mean-success" data-toc-modified-id="Plot-mean-success-0.2.0.3"><span class="toc-item-num">0.2.0.3&nbsp;&nbsp;</span>Plot mean success</a></span></li><li><span><a href="#Find-success-rate" data-toc-modified-id="Find-success-rate-0.2.0.4"><span class="toc-item-num">0.2.0.4&nbsp;&nbsp;</span>Find success rate</a></span></li><li><span><a href="#Find-root" data-toc-modified-id="Find-root-0.2.0.5"><span class="toc-item-num">0.2.0.5&nbsp;&nbsp;</span>Find root</a></span></li><li><span><a href="#Find-ps" data-toc-modified-id="Find-ps-0.2.0.6"><span class="toc-item-num">0.2.0.6&nbsp;&nbsp;</span>Find ps</a></span></li><li><span><a href="#Plot-sigma-estimates" data-toc-modified-id="Plot-sigma-estimates-0.2.0.7"><span class="toc-item-num">0.2.0.7&nbsp;&nbsp;</span>Plot sigma estimates</a></span></li><li><span><a href="#Plot-p-estimates" data-toc-modified-id="Plot-p-estimates-0.2.0.8"><span class="toc-item-num">0.2.0.8&nbsp;&nbsp;</span>Plot p estimates</a></span></li></ul></li></ul></li><li><span><a href="#Recurrent-calculations" data-toc-modified-id="Recurrent-calculations-0.3"><span class="toc-item-num">0.3&nbsp;&nbsp;</span>Recurrent calculations</a></span></li></ul></li><li><span><a href="#Probability-threshold" data-toc-modified-id="Probability-threshold-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Probability threshold</a></span><ul class="toc-item"><li><span><a href="#A-general-example" data-toc-modified-id="A-general-example-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>A general example</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#How-long-to-calculate-a-rate" data-toc-modified-id="How-long-to-calculate-a-rate-1.1.0.1"><span class="toc-item-num">1.1.0.1&nbsp;&nbsp;</span>How long to calculate a rate</a></span></li></ul></li></ul></li><li><span><a href="#Testing-root-finding" data-toc-modified-id="Testing-root-finding-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Testing root finding</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Test-the-function" data-toc-modified-id="Test-the-function-1.2.0.1"><span class="toc-item-num">1.2.0.1&nbsp;&nbsp;</span>Test the function</a></span></li><li><span><a href="#Test-the-complete-function" data-toc-modified-id="Test-the-complete-function-1.2.0.2"><span class="toc-item-num">1.2.0.2&nbsp;&nbsp;</span>Test the complete function</a></span></li></ul></li></ul></li><li><span><a href="#Comparisons" data-toc-modified-id="Comparisons-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Comparisons</a></span><ul class="toc-item"><li><span><a href="#Training-time" data-toc-modified-id="Training-time-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Training time</a></span></li><li><span><a href="#tau_z" data-toc-modified-id="tau_z-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>tau_z</a></span></li><li><span><a href="#IPI" data-toc-modified-id="IPI-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>IPI</a></span></li><li><span><a href="#Minicolumns" data-toc-modified-id="Minicolumns-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>Minicolumns</a></span></li><li><span><a href="#Hypercolumns" data-toc-modified-id="Hypercolumns-1.3.5"><span class="toc-item-num">1.3.5&nbsp;&nbsp;</span>Hypercolumns</a></span></li><li><span><a href="#Training-time-illustrative-example" data-toc-modified-id="Training-time-illustrative-example-1.3.6"><span class="toc-item-num">1.3.6&nbsp;&nbsp;</span>Training time illustrative example</a></span></li></ul></li><li><span><a href="#Complete-plot" data-toc-modified-id="Complete-plot-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Complete plot</a></span><ul class="toc-item"><li><span><a href="#First-plot" data-toc-modified-id="First-plot-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>First plot</a></span></li><li><span><a href="#Reliability-plot" data-toc-modified-id="Reliability-plot-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Reliability plot</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Preamble

# %%
import  pprint
import  subprocess 
import sys 
sys.path.append('../')

import numpy as np
import scipy as sp
import statsmodels.api as sm
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
import seaborn as sns

# %matplotlib inline
plt.rcParams['figure.figsize'] = (14, 10)

np.set_printoptions(suppress=True, precision=5)

sns.set(font_scale=3.5)
sns.set_style("whitegrid", {'axes.grid': False})

from network import Protocol, NetworkManager, Network
from patterns_representation import PatternsRepresentation
from analysis_functions import calculate_persistence_time, calculate_recall_quantities
from plotting_functions import plot_weight_matrix, plot_network_activity_angle, plot_persistent_matrix

epsilon = 10e-80
vmin = -3.0
remove = 0.010

# %% [markdown]
# ## Graphical parameters

# %%
dt = 0.001
remove = 0.010

# %%
lw = 8
ms = 15
alpha_graph = 0.3
colors = sns.color_palette()

# %% [markdown]
# ## Functions

# %% [markdown]
# #### Number of iterations

# %%
def number_of_iterations(start_size, desired_size=0.1):
    
    iterations = int(np.log(desired_size/ start_size) / np.log(0.5)) + 1

    return iterations

# %% [markdown]
# Some small function test of the function

# %%
x = 5
final_size = 0.01
iterations = number_of_iterations(start_size=x, desired_size=final_size)
print('number of iterations', iterations)
print('initial size', x)
for i in range(iterations):
    x = x * 0.5
    print(x)
print('final size', x)
# Out:
# number of iterations 9
# initial size 5
# 2.5
# 1.25
# 0.625
# 0.3125
# 0.15625
# 0.078125
# 0.0390625
# 0.01953125
# 0.009765625
# final size 0.009765625

# %%
n_samples = 1000
p = 0.8
start_size = 5.0
tolerance = 2.0

std = np.sqrt(p * (1 -p) / n_samples)
final_size = 0.1

iterations = int(np.log(final_size/ start_size) / np.log(0.5)) + 1
print(iterations)
print(std)
# Out:
# 6
# 0.012649110640673518

# %% [markdown]
# #### Sigma sweep

# %%
def run_sigma_sweep(sigma_number, samples, sigma_max, manager, T_persistence=0.050):

    manager.set_persistent_time_with_adaptation_gain(T_persistence=T_persistence)
    tau_s = manager.nn.tau_s
    T_recall = T_persistence * manager.nn.minicolumns
    T_cue = 3 * tau_s
    nr = manager.canonical_network_representation

    sigma_vector = np.linspace(0, sigma_max, num=sigma_number)

    successes_collection = np.zeros((sigma_number, samples))
    persistent_times_collection = {index: [] for index in range(sigma_number)}
    sequence_collection = {index: [] for index in range(sigma_number)}

    for index, sigma in enumerate(sigma_vector):
        manager.nn.sigma_out = sigma
        manager.nn.sigma_in = sigma * np.sqrt(2 / tau_s)
        for sample in range(samples):
            aux = calculate_recall_quantities(manager, nr, T_recall, T_cue, remove=remove,
                                              reset=True, empty_history=True)
            success, pattern_sequence, persistent_times, timings = aux
            successes_collection[index, sample] = success
            persistent_times_collection[index].append(persistent_times[:n_patterns])
            sequence_collection[index].append(pattern_sequence)

    results_dic = {'manager': manager, 'sigma_vector': sigma_vector, 'success': successes_collection,
                   'persistent times': persistent_times_collection, 'sequences': sequence_collection,
                   'T_persistence': T_persistence}

    return results_dic

# %% [markdown]
# #### Plot mean success

# %%
def plot_mean_success_vs_sigma(results_dictionary, n_samples, index=0, label=0, ax=None, add_zero_axis=False):

    if ax is None:
        fig = plt.figure()
        ax = fig.add_subplot(111)

    successes_collection = results_dictionary['success']
    sigma_vector = results_dictionary['sigma_vector']

    std = successes_collection.std(axis=1)
    mean_success = successes_collection.mean(axis=1)
    ci_low, ci_upp = sm.stats.proportion_confint(mean_success * n_samples, n_samples, alpha=0.05, method='normal')

    # Plot the mean
    ax.plot(sigma_vector, mean_success, 'o-', lw=lw, ms=ms, color=colors[index], label=label)
    
    if False:
        # Plot sigma05
        sigma09_arg = np.where(mean_success <= 0.9)[0]
        if sigma09_arg.size > 0:
            sigma09 = sigma_vector[sigma09_arg[0]]
            ax.plot(sigma09, 0.9, '*', ms=(ms + 20), color='black')

        sigma01_arg = np.where(mean_success <= 0.1)[0]
        if sigma01_arg.size > 0:
            sigma01 = sigma_vector[sigma01_arg[0]]
            ax.plot(sigma01, 0.1, '*', ms=(ms + 20), color='black')
    
    # Plot the interval
    low = ci_low
    low[low < 0.0] = 0.0
    high = ci_upp
    ax.fill_between(sigma_vector, low, high, color=colors[index], alpha=alpha_graph)

    
    if add_zero_axis:
        ax.axhline(0, ls='--', color='gray')
        ax.axvline(0, ls='--', color='gray')

    ax.set_xlabel(r'$\sigma$')
    ax.set_ylabel('Success rate')
    ax.legend(frameon=False)

    return ax

# %% [markdown]
# #### Find success rate

# %%
def find_success_rate(manager, n_samples, sigma_out, T_persistence):
    manager.nn.sigma_in = sigma_out * np.sqrt(2 / manager.nn.tau_s)
    manager.nn.sigma_out = sigma_out
    T_recall = T_persistence * minicolumns
    T_cue = manager.nn.tau_s
    I_cue = 0
    nr = manager.canonical_network_representation
    success_list = []
    for index in range(n_samples):
        aux = calculate_recall_quantities(manager, nr, T_recall, T_cue, remove=remove, reset=True, empty_history=True)
        success, pattern_sequence, persistent_times, timings = aux
        success_list.append(success)

    return np.mean(success_list)

# %% [markdown]
# #### Find root

# %%
def find_root(manager, p_root, total_length, n_samples, T_persistence, factor=1.0, verbose=False):
    final_size = 0.01
    iterations = number_of_iterations(start_size=total_length, desired_size=final_size)
    left = 0.0
    right = total_length
    tolerance = factor * np.sqrt(p_root * (1 - p_root) / n_samples)
    if verbose:
        print('number of iterations', iterations)
        print('left = ', left, 'right = ', right)
        print('************')
    for iteration in range(iterations):
        sigma_test = (left + right) * 0.5
        result = find_success_rate(manager, n_samples, sigma_test, T_persistence)
        # First we check whether we are closer than the standar deviation for bernoulli estimates. 
        tol = np.abs(result - p_root) / tolerance
        
        if verbose:
            print('number of iteration : ', iteration)
            print('left = ', left, ' right = ', right, 'length = ', right - left)
            print('sigma test =', sigma_test, ' result =', result, ' p_root = ', p_root)
            print('tol = ', tol, ' factor  * std = ', tolerance)
            print('----')
            
        if tol < 1:
            break
        elif result > p_root:
            left = sigma_test
        elif result <= p_root:
            right = sigma_test
    
    length = right - left

    return result, sigma_test, length

# %% [markdown]
# #### Find ps

# %%
def find_p(training_time, ipi, tau_z_pre, minicolumns, hypercolumns, T_persistence, tau_z_post=0.005,
           n_samples=100, factor=1.5, total_length=50, p_roots=[0.5], verbose=False):
    
    strict_maximum = True

    g_a = 1.0
    g_I = 2.0
    tau_a = 0.250
    G = 1.0
    sigma_out = 0.0
    tau_s = 0.010
    tau_z_pre = tau_z_pre
    tau_z_post = tau_z_post

    hypercolumns = hypercolumns
    minicolumns = minicolumns
    n_patterns = minicolumns

    # Training protocol
    training_time_base = training_time
    training_times = [training_time_base for i in range(n_patterns)]
    inter_pulse_interval_base = ipi
    inter_pulse_intervals = [inter_pulse_interval_base for i in range(n_patterns)]
    inter_sequence_interval = 0.0
    resting_time = 2.0
    epochs = 1
    T_persistence = T_persistence

    # Manager properties
    values_to_save = ['o']


    # Neural Network
    nn = Network(hypercolumns, minicolumns, G=G, tau_s=tau_s, tau_z_pre=tau_z_pre, tau_z_post=tau_z_post,
                 tau_a=tau_a, g_a=g_a, g_I=g_I, sigma_out=sigma_out, epsilon=epsilon, prng=np.random,
                 strict_maximum=strict_maximum, perfect=False, normalized_currents=True)


    # Build the manager
    manager = NetworkManager(nn=nn, dt=dt, values_to_save=values_to_save)
    # Build the representation
    representation = PatternsRepresentation(manager.canonical_activity_representation[:n_patterns],
                                            minicolumns=minicolumns)

    # Build the protocol
    protocol = Protocol()
    protocol.simple_protocol(representation, training_times=training_times, inter_pulse_intervals=inter_pulse_intervals, inter_sequence_interval=inter_sequence_interval, epochs=epochs, resting_time=resting_time)

    # Run the protocol
    timed_input = manager.run_network_protocol_offline(protocol=protocol)
    manager.set_persistent_time_with_adaptation_gain(T_persistence=T_persistence)


    # Find the sigmas 
    results_dic = {}
    
    for p in p_roots: 
        results_dic[p] = find_root(manager, p, total_length, n_samples, T_persistence, 
                                   factor=factor, verbose=verbose)

    return results_dic

# %% [markdown]
# #### Plot sigma estimates

# %%
def plot_sigma_estimates(results_dictionary, title=' ', ax=None, legend=True, bars=True, add_zero_axis=False):

    if ax is None:
        fig = plt.figure()
        ax = fig.add_subplot(111)

    x_vector = results_dictionary['input']
    xlabel = results_dictionary['label']

    p_labels = results_dictionary['p_labels']
    p_roots = results_dictionary['p_roots']

    # Sigmas
    for index, (p_root, p_label) in enumerate(zip(p_roots, p_labels)):
        stored_dictionary = results_dictionary[p_root]
        sigma_vector = stored_dictionary['sigma']
        length_vector = stored_dictionary['length']
        label = r'$\sigma_{' + p_label + '}$'
        ax.plot(x_vector, sigma_vector, 'o-', lw=lw, ms=ms, color=colors[index], label=label)
        
        if bars:
            up = sigma_vector + length_vector * 0.5
            down = sigma_vector - length_vector * 0.5
            down[down < 0.0] = 0.0
            ax.fill_between(x_vector, up, down, color=colors[index], alpha=alpha_graph)

    ax.set_xlabel(xlabel)
    ax.set_ylabel(r'$\sigma_{50}$')
    
    if add_zero_axis:
        ax.axhline(0, ls='--', color='gray')
        ax.axvline(0, ls='--', color='gray')

    if legend:
        ax.legend(frameon=False)
        ax.set_title(title)
    
    return ax

# %% [markdown]
# #### Plot p estimates

# %%
def plot_p_estimates(results_dictionary, n_samples, title=' ', ax=None, legend=True, add_zero_axis=False):
    
    if ax is None:
        fig = plt.figure()
        ax = fig.add_subplot(111)
    
    x_vector = results_dictionary['input']
    xlabel = results_dictionary['label']

    p_labels = results_dictionary['p_labels']
    p_roots = results_dictionary['p_roots']

    # Sigmas
    for index, (p_root, p_label) in enumerate(zip(p_roots, p_labels)):
        stored_dictionary = results_dictionary[p_root]
        p_vector = stored_dictionary['result']
        label = r'$p_{' + p_label + '}$'
        ax.plot(x_vector, p_vector, 'o-', lw=lw, ms=ms, color=colors[index], label=label)
        ci_low, ci_upp = sm.stats.proportion_confint(p_vector * n_samples, n_samples, 
                                                     alpha=0.05, method='normal')

        # Plot the interval
        low = ci_low
        low[low < 0.0] = 0.0
        high = ci_upp
        ax.fill_between(x_vector, low, high, color=colors[index], alpha=alpha_graph)

    ax.set_xlabel(xlabel)
    ax.set_ylabel(r'$p_{50}$')

    if add_zero_axis:
        ax.axhline(0, ls='--', color='gray')
        ax.axvline(0, ls='--', color='gray')
        ax.set_ylim([-0.1, 1.0])

    #for p_root in p_roots:
    #    ax.axhline(p_root, ls='--', color='gray')
    
    if legend:
        ax.legend(frameon=False)
        ax.set_title(title)
    
    return ax

# %% [markdown]
# ## Recurrent calculations

# %%
n_set = [100, 150, 250, 500, 1000]
p_root = 0.8
print('cofidences for p = ' + str(p_root))
for n in n_set:
    print('n = ', n)
    print('confidence = ', 1.5 * np.sqrt(p_root * (1 - p_root) / n))
# Out:
# cofidences for p = 0.8
# n =  100
# confidence =  0.06
# n =  150
# confidence =  0.04898979485566356
# n =  250
# confidence =  0.03794733192202055
# n =  500
# confidence =  0.026832815729997475
# n =  1000
# confidence =  0.018973665961010275

# %%
n_set = [100, 150, 250, 500, 1000]
p_root = 0.2
print('cofidences for p = ' + str(p_root))
for n in n_set:
    print('n = ', n)
    print('confidence = ', 1.5 * np.sqrt(p_root * (1 - p_root) / n))
# Out:
# cofidences for p = 0.2
# n =  100
# confidence =  0.06
# n =  150
# confidence =  0.04898979485566357
# n =  250
# confidence =  0.03794733192202056
# n =  500
# confidence =  0.02683281572999748
# n =  1000
# confidence =  0.01897366596101028

# %% [markdown]
# # Probability threshold

# %% [markdown]
# ## A general example

# %%
# %%time

strict_maximum = True

g_a = 1.0
g_I = 2.0
tau_a = 0.250
G = 1.0
sigma_out = 0.0
tau_s = 0.010
tau_z_pre = 0.025
tau_z_post = 0.005

hypercolumns = 1
minicolumns = 5
n_patterns = minicolumns

# Training protocol
training_time_base = 1.00
training_times = [training_time_base for i in range(n_patterns)]
inter_pulse_interval_base = 0.0
inter_pulse_intervals = [inter_pulse_interval_base for i in range(n_patterns)]
inter_sequence_interval = 0.0
resting_time = 0.0
epochs = 1
T_persistence = 0.050

# Manager properties
values_to_save = ['o']

# Neural Network
nn = Network(hypercolumns, minicolumns, G=G, tau_s=tau_s, tau_z_pre=tau_z_pre, tau_z_post=tau_z_post,
             tau_a=tau_a, g_a=g_a, g_I=g_I, sigma_out=sigma_out, epsilon=epsilon, prng=np.random,
             strict_maximum=strict_maximum, perfect=False, normalized_currents=True)


# Build the manager
manager = NetworkManager(nn=nn, dt=dt, values_to_save=values_to_save)
# Build the representation
representation = PatternsRepresentation(manager.canonical_activity_representation[:n_patterns],
                                        minicolumns=minicolumns)

# Build the protocol
protocol = Protocol()
protocol.simple_protocol(representation, training_times=training_times, inter_pulse_intervals=inter_pulse_intervals, inter_sequence_interval=inter_sequence_interval, epochs=epochs, resting_time=resting_time)

# Run the protocol
timed_input = manager.run_network_protocol_offline(protocol=protocol)

sigma_number = 30
n_samples = 250
sigma_max = 5

results_dictionary_simple = run_sigma_sweep(sigma_number, n_samples, sigma_max, manager, T_persistence=T_persistence)
# Out:
# CPU times: user 2min 28s, sys: 144 ms, total: 2min 28s
# Wall time: 2min 28s

# %%
ax = plot_mean_success_vs_sigma(results_dictionary_simple, n_samples=n_samples, index=0, label=0, ax=None)
ax.axhline(0.1, ls='--', color='green')
ax.axhline(0.9, ls='--', color='green')

p_root = 0.90
total_length = 5.0
factor = 1.0
result9, sigma_test9, length = find_root(manager, p_root, total_length, n_samples, 
                                       T_persistence=T_persistence, factor=factor, verbose=False)
ax.plot(sigma_test9, result9, '*', ms=ms + 20, color='red')

p_root = 0.1
result1, sigma_test1, length = find_root(manager, p_root, total_length, n_samples, 
                                       T_persistence=T_persistence, factor=factor, verbose=False)
ax.plot(sigma_test1, result1, '*', ms=ms + 20, color='red');

# %%
successes_collection = results_dictionary_simple['success']
sigma_vector = results_dictionary_simple['sigma_vector']

std = successes_collection.std(axis=1)
mean_success = successes_collection.mean(axis=1)

ci_low, ci_upp = sm.stats.proportion_confint(mean_success * n_samples, n_samples, alpha=0.05, method='normal')
diff = ci_upp - ci_low
plt.plot(mean_success, diff)
plt.xlabel('mean success')
plt.ylabel('confidence width');

# %%
plt.plot(sigma_vector, diff)
plt.xlabel(r'$\sigma$')
plt.ylabel('confidence width')

plt.axvline(sigma_test1, ls='--', color='red')
plt.axvline(sigma_test9, ls='--', color='red')

# %% [markdown]
# #### How long to calculate a rate

# %%
# %%time
n_samples = 100
sigma_out = 1.0
r = find_success_rate(manager, n_samples, sigma_out, T_persistence)
print(sigma_out, r)
# Out:
# 1.0 0.87
# CPU times: user 1.83 s, sys: 0 ns, total: 1.83 s
# Wall time: 1.83 s

# %%
# %%time
n_samples = 250
r = find_success_rate(manager, n_samples, sigma_out, T_persistence)
print(sigma_out, r)
# Out:
# 1.0 0.908
# CPU times: user 4.59 s, sys: 8 ms, total: 4.6 s
# Wall time: 4.6 s

# %%
# %%time
n_samples = 500
r = find_success_rate(manager, n_samples, sigma_out, T_persistence)
print(sigma_out, r)
# Out:
# 1.0 0.892
# CPU times: user 9.3 s, sys: 0 ns, total: 9.3 s
# Wall time: 9.3 s

# %%
# %%time
n_samples = 1000
r = find_success_rate(manager, n_samples, sigma_out, T_persistence)
print(sigma_out, r)
# Out:
# 1.0 0.871
# CPU times: user 18.5 s, sys: 4 ms, total: 18.5 s
# Wall time: 18.5 s

# %% [markdown]
# ## Testing root finding

# %% [markdown]
# #### Test the function

# %%
# %%time
p_root = 0.90
n_samples = 250
total_length = 5
factor = 1.5
result, sigma_test, length = find_root(manager, p_root, total_length, n_samples, 
                                       T_persistence=T_persistence, factor=factor, verbose=True)
print('results')
print('sigma test = ', sigma_test, ' result = ', result, ' length = ', length)
# Out:
# number of iterations 9
# left =  0.0 right =  5
# ************
# number of iteration :  0
# left =  0.0  right =  5 length =  5.0
# sigma test = 2.5  result = 0.404  p_root =  0.9
# tol =  17.427663549372404  factor  * std =  0.028460498941515408
# ----
# number of iteration :  1
# left =  0.0  right =  2.5 length =  2.5
# sigma test = 1.25  result = 0.78  p_root =  0.9
# tol =  4.21637021355784  factor  * std =  0.028460498941515408
# ----
# number of iteration :  2
# left =  0.0  right =  1.25 length =  1.25
# sigma test = 0.625  result = 0.996  p_root =  0.9
# tol =  3.3730961708462712  factor  * std =  0.028460498941515408
# ----
# number of iteration :  3
# left =  0.625  right =  1.25 length =  0.625
# sigma test = 0.9375  result = 0.924  p_root =  0.9
# tol =  0.8432740427115687  factor  * std =  0.028460498941515408
# ----
# results
# sigma test =  0.9375  result =  0.924  length =  0.625
# CPU times: user 18.5 s, sys: 20 ms, total: 18.5 s
# Wall time: 18.5 s

# %% [markdown]
# #### Test the complete function

# %%
# %%time
training_time = 0.100
ipi = 0.0
tau_z_pre = 0.025
tau_z_post = 0.005
n_samples = 500
factor = 1.5
length = 60
p_roots = [0.5]
results_dic = find_p(training_time, ipi, tau_z_pre, minicolumns, hypercolumns, T_persistence, p_roots=p_roots,
                     tau_z_post=tau_z_post, n_samples=n_samples, factor=factor, total_length=length, verbose=True)
# Out:
# number of iterations 13
# left =  0.0 right =  60
# ************
# number of iteration :  0
# left =  0.0  right =  60 length =  60.0
# sigma test = 30.0  result = 0.0  p_root =  0.5
# tol =  14.907119849998598  factor  * std =  0.03354101966249685
# ----
# number of iteration :  1
# left =  0.0  right =  30.0 length =  30.0
# sigma test = 15.0  result = 0.0  p_root =  0.5
# tol =  14.907119849998598  factor  * std =  0.03354101966249685
# ----
# number of iteration :  2
# left =  0.0  right =  15.0 length =  15.0
# sigma test = 7.5  result = 0.0  p_root =  0.5
# tol =  14.907119849998598  factor  * std =  0.03354101966249685
# ----
# number of iteration :  3
# left =  0.0  right =  7.5 length =  7.5
# sigma test = 3.75  result = 0.006  p_root =  0.5
# tol =  14.728234411798613  factor  * std =  0.03354101966249685
# ----
# number of iteration :  4
# left =  0.0  right =  3.75 length =  3.75
# sigma test = 1.875  result = 0.038  p_root =  0.5
# ...

# %%
result, sigma, length = results_dic[0.5]
print('result', result, 'sigma', sigma, 'length', length)
# Out:
# result 0.526 sigma 0.703125 length 0.46875

# %% [markdown]
# ## Comparisons

# %%
num = 25
n_samples = 1500
factor = 1.96
total_length = 4.0
p_roots = [0.5]

# %% [markdown]
# ### Training time

# %%
# %%time

input_vector = np.linspace(0.050, 1.00, num=num)
label = r'$T_p (s)$'

results_dictionary = {'input':input_vector, 'label': label,  
                         'p_roots': p_roots, 'p_labels': [str(x) for x in p_roots]}
for p_root in p_roots:
    stored_dic = {}
    stored_dic['sigma'] = np.zeros(num)
    stored_dic['result'] = np.zeros(num)
    stored_dic['length'] = np.zeros(num)
    results_dictionary[p_root] = stored_dic


training_time = 0.100
ipi = 0.0
tau_z_pre = 0.025
tau_z_post = 0.015
minicolumns = 5
hypercolumns = 1
T_persistence = 0.050


for index, x in enumerate(input_vector):
    print('***')
    print(index, x)
    print('***')
    training_time = x
    aux = find_p(training_time, ipi, tau_z_pre, minicolumns, hypercolumns, T_persistence, tau_z_post=tau_z_post, 
           n_samples=n_samples, total_length=total_length, factor=factor, p_roots=p_roots, verbose=False)
    
    for p_root in p_roots:
        result, sigma, length = aux[p_root]
        results_dictionary[p_root]['result'][index] = result
        results_dictionary[p_root]['sigma'][index] = sigma
        results_dictionary[p_root]['length'][index] = length

results_dictionary_tt = results_dictionary
# Out:
# ***
# 0 0.05
# ***
# ***
# 1 0.08958333333333333
# ***
# ***
# 2 0.12916666666666665
# ***
# ***
# 3 0.16875
# ***
# ***
# 4 0.20833333333333331
# ***
# ***
# 5 0.24791666666666667
# ***
# ***
# 6 0.2875
# ***
# ***
# 7 0.32708333333333334
# ***
# ***
# 8 0.36666666666666664
# ***
# ***
# 9 0.40624999999999994
# ***
# ***
# 10 0.4458333333333333
# ***
# ***
# 11 0.48541666666666666
# ***
# ***
# 12 0.525
# ***
# ***
# 13 0.5645833333333333
# ***
# ***
# 14 0.6041666666666667
# ***
# ***
# 15 0.64375
# ***
# ***
# 16 0.6833333333333333
# ***
# ***
# 17 0.7229166666666667
# ***
# ***
# 18 0.7625
# ***
# ***
# 19 0.8020833333333334
# ***
# ***
# 20 0.8416666666666667
# ***
# ***
# 21 0.88125
# ***
# ***
# 22 0.9208333333333334
# ***
# ***
# 23 0.9604166666666667
# ***
# ***
# 24 1.0
# ***
# CPU times: user 53min 56s, sys: 668 ms, total: 53min 56s
# Wall time: 53min 57s

# %%
results_dictionary = results_dictionary_tt
plot_sigma_estimates(results_dictionary, title=' ', ax=None)
plot_p_estimates(results_dictionary, n_samples=n_samples, title=' ', ax=None)

# %% [markdown]
# ### tau_z

# %%
# %%time
input_vector = np.linspace(0.025, 0.150, num=num)
label = r'$\tau_{z_{pre}} (s)$'

results_dictionary = {'input':input_vector, 'label': label,  
                         'p_roots': p_roots, 'p_labels': [str(x) for x in p_roots]}
for p_root in p_roots:
    stored_dic = {}
    stored_dic['sigma'] = np.zeros(num)
    stored_dic['result'] = np.zeros(num)
    stored_dic['length'] = np.zeros(num)
    results_dictionary[p_root] = stored_dic


training_time = 0.100
ipi = 0.0
tau_z_pre = 0.025
tau_z_post = 0.015
minicolumns = 5
hypercolumns = 1
T_persistence = 0.050


for index, x in enumerate(input_vector):
    print('***')
    print(index, x)
    print('***')
    tau_z_pre = x
    aux = find_p(training_time, ipi, tau_z_pre, minicolumns, hypercolumns, T_persistence, tau_z_post=tau_z_post, 
           n_samples=n_samples, total_length=total_length, factor=factor, p_roots=p_roots, verbose=False)
    
    for p_root in p_roots:
        result, sigma, length = aux[p_root]
        results_dictionary[p_root]['result'][index] = result
        results_dictionary[p_root]['sigma'][index] = sigma
        results_dictionary[p_root]['length'][index] = length


results_dictionary_tau_z = results_dictionary
# Out:
# ***
# 0 0.025
# ***
# ***
# 1 0.030208333333333334
# ***
# ***
# 2 0.035416666666666666
# ***
# ***
# 3 0.040625
# ***
# ***
# 4 0.04583333333333334
# ***
# ***
# 5 0.051041666666666666
# ***
# ***
# 6 0.05625
# ***
# ***
# 7 0.06145833333333333
# ***
# ***
# 8 0.06666666666666667
# ***
# ***
# 9 0.071875
# ***
# ***
# 10 0.07708333333333334
# ***
# ***
# 11 0.08229166666666667
# ***
# ***
# 12 0.0875
# ***
# ***
# 13 0.09270833333333334
# ***
# ***
# 14 0.09791666666666665
# ***
# ***
# 15 0.103125
# ***
# ***
# 16 0.10833333333333334
# ***
# ***
# 17 0.11354166666666665
# ***
# ***
# 18 0.11875
# ***
# ***
# 19 0.12395833333333334
# ***
# ***
# 20 0.12916666666666665
# ***
# ***
# 21 0.134375
# ***
# ***
# 22 0.13958333333333334
# ***
# ***
# 23 0.14479166666666665
# ***
# ***
# 24 0.15
# ***
# CPU times: user 1h 16min 11s, sys: 444 ms, total: 1h 16min 11s
# Wall time: 1h 16min 11s

# %%
results_dictionary = results_dictionary_tau_z
ax = plot_sigma_estimates(results_dictionary, title=' ', ax=None)
ax.axvline(tau_z_post, ls='--', color='red', label=r'$\tau_{z_{post}}$')
ax.legend(frameon=False)
plot_p_estimates(results_dictionary, n_samples=n_samples, title=' ', ax=None)

# %% [markdown]
# ### IPI

# %%
# %%time

input_vector = np.linspace(0.000, 0.100, num=num)
label = r'$\Delta T_p$ (s)'

results_dictionary = {'input':input_vector, 'label': label,  
                         'p_roots': p_roots, 'p_labels': [str(x) for x in p_roots]}
for p_root in p_roots:
    stored_dic = {}
    stored_dic['sigma'] = np.zeros(num)
    stored_dic['result'] = np.zeros(num)
    stored_dic['length'] = np.zeros(num)
    results_dictionary[p_root] = stored_dic


training_time = 0.100
ipi = 0.0
tau_z_pre = 0.025
tau_z_post = 0.015
minicolumns = 5
hypercolumns = 1
T_persistence = 0.050


for index, x in enumerate(input_vector):
    print('***')
    print(index, x)
    print('***')
    ipi = x
    aux = find_p(training_time, ipi, tau_z_pre, minicolumns, hypercolumns, T_persistence, tau_z_post=tau_z_post, 
           n_samples=n_samples, total_length=total_length, factor=factor, p_roots=p_roots, verbose=False)
    
    for p_root in p_roots:
        result, sigma, length = aux[p_root]
        results_dictionary[p_root]['result'][index] = result
        results_dictionary[p_root]['sigma'][index] = sigma
        results_dictionary[p_root]['length'][index] = length

results_dictionary_ipi = results_dictionary
# Out:
# ***
# 0 0.0
# ***
# ***
# 1 0.004166666666666667
# ***
# ***
# 2 0.008333333333333333
# ***
# ***
# 3 0.0125
# ***
# ***
# 4 0.016666666666666666
# ***
# ***
# 5 0.020833333333333332
# ***
# ***
# 6 0.025
# ***
# ***
# 7 0.029166666666666667
# ***
# ***
# 8 0.03333333333333333
# ***
# ***
# 9 0.0375
# ***
# ***
# 10 0.041666666666666664
# ***
# ***
# 11 0.04583333333333333
# ***
# ***
# 12 0.05
# ***
# ***
# 13 0.05416666666666667
# ***
# ***
# 14 0.058333333333333334
# ***
# ***
# 15 0.0625
# ***
# ***
# 16 0.06666666666666667
# ***
# ***
# 17 0.07083333333333333
# ***
# ***
# 18 0.075
# ***
# ***
# 19 0.07916666666666666
# ***
# ***
# 20 0.08333333333333333
# ***
# ***
# 21 0.0875
# ***
# ***
# 22 0.09166666666666666
# ***
# ***
# 23 0.09583333333333333
# ***
# ***
# 24 0.1
# ***
# CPU times: user 54min 48s, sys: 400 ms, total: 54min 48s
# Wall time: 54min 49s

# %%
results_dictionary = results_dictionary_ipi
plot_sigma_estimates(results_dictionary, title=' ', ax=None)
plot_p_estimates(results_dictionary, n_samples=n_samples, title=' ', ax=None)

# %% [markdown]
# ### Minicolumns

# %%
# %%time

input_vector = np.arange(5, 35, 5)
num = input_vector.size
label = 'sequence length'

results_dictionary = {'input':input_vector, 'label': label,  
                         'p_roots': p_roots, 'p_labels': [str(x) for x in p_roots]}
for p_root in p_roots:
    stored_dic = {}
    stored_dic['sigma'] = np.zeros(num)
    stored_dic['result'] = np.zeros(num)
    stored_dic['length'] = np.zeros(num)
    results_dictionary[p_root] = stored_dic


training_time = 0.100
ipi = 0.0
tau_z_pre = 0.025
tau_z_post = 0.015
vminicolumns = 5
hypercolumns = 1
T_persistence = 0.050


for index, x in enumerate(input_vector):
    print('***')
    print(index, x)
    print('***')
    minicolumns = x
    aux = find_p(training_time, ipi, tau_z_pre, minicolumns, hypercolumns, T_persistence, tau_z_post=tau_z_post, 
           n_samples=n_samples, total_length=total_length, factor=factor, p_roots=p_roots, verbose=False)
    
    for p_root in p_roots:
        result, sigma, length = aux[p_root]
        results_dictionary[p_root]['result'][index] = result
        results_dictionary[p_root]['sigma'][index] = sigma
        results_dictionary[p_root]['length'][index] = length


results_dictionary_minicolumns = results_dictionary
# Out:
# ***
# 0 5
# ***
# ***
# 1 10
# ***
# ***
# 2 15
# ***
# ***
# 3 20
# ***
# ***
# 4 25
# ***
# ***
# 5 30
# ***
# CPU times: user 2h 56min 26s, sys: 876 ms, total: 2h 56min 27s
# Wall time: 2h 56min 26s

# %%
results_dictionary = results_dictionary_minicolumns
plot_sigma_estimates(results_dictionary, title=' ', ax=None)
plot_p_estimates(results_dictionary, n_samples=n_samples, title=' ', ax=None)

# %% [markdown]
# ### Hypercolumns

# %%
# %%time

input_vector = np.array([1, 5, 10, 15, 20, 25, 30], dtype='int')
num = input_vector.size
label = 'hypercolumns'

results_dictionary = {'input':input_vector, 'label': label,  
                         'p_roots': p_roots, 'p_labels': [str(x) for x in p_roots]}
for p_root in p_roots:
    stored_dic = {}
    stored_dic['sigma'] = np.zeros(num)
    stored_dic['result'] = np.zeros(num)
    stored_dic['length'] = np.zeros(num)
    results_dictionary[p_root] = stored_dic


training_time = 0.100
ipi = 0.0
tau_z_pre = 0.025
tau_z_post = 0.015
minicolumns = 5
hypercolumns = 1
T_persistence = 0.050


for index, x in enumerate(input_vector):
    print('***')
    print(index, x)
    print('***')
    hypercolumns = x
    aux = find_p(training_time, ipi, tau_z_pre, minicolumns, hypercolumns, T_persistence, tau_z_post=tau_z_post, 
           n_samples=n_samples, total_length=total_length, factor=factor, p_roots=p_roots, verbose=False)
    
    for p_root in p_roots:
        result, sigma, length = aux[p_root]
        results_dictionary[p_root]['result'][index] = result
        results_dictionary[p_root]['sigma'][index] = sigma
        results_dictionary[p_root]['length'][index] = length


results_dictionary_hyper = results_dictionary
# Out:
# ***
# 0 1
# ***
# ***
# 1 5
# ***
# ***
# 2 10
# ***
# ***
# 3 15
# ***
# ***
# 4 20
# ***
# ***
# 5 25
# ***
# ***
# 6 30
# ***
# CPU times: user 51min 21s, sys: 1min 40s, total: 53min 2s
# Wall time: 21min 3s

# %%
results_dictionary = results_dictionary_hyper
plot_sigma_estimates(results_dictionary, title=' ', ax=None)
plot_p_estimates(results_dictionary, n_samples=n_samples, title=' ', ax=None)

# %% [markdown]
# ### Training time illustrative example

# %%
# %%time

strict_maximum = True

g_a = 1.0
g_I = 2.0
tau_a = 0.250
G = 1.0
sigma_out = 0.0
tau_s = 0.010
tau_z_pre = 0.025
tau_z_post = 0.015

hypercolumns = 1
minicolumns = 5
n_patterns = minicolumns

# Training protocol
training_time_base = 0.100
training_times = [training_time_base for i in range(n_patterns)]
inter_pulse_interval_base = 0.0
inter_pulse_intervals = [inter_pulse_interval_base for i in range(n_patterns)]
inter_sequence_interval = 0.0
resting_time = 0.0
epochs = 1
T_persistence = 0.050

# Manager properties
dt = 0.001
values_to_save = ['o']

# Neural Network
nn = Network(hypercolumns, minicolumns, G=G, tau_s=tau_s, tau_z_pre=tau_z_pre, tau_z_post=tau_z_post,
             tau_a=tau_a, g_a=g_a, g_I=g_I, sigma_out=sigma_out, epsilon=epsilon, prng=np.random,
             strict_maximum=strict_maximum, perfect=False, normalized_currents=True)


# Build the manager
manager = NetworkManager(nn=nn, dt=dt, values_to_save=values_to_save)
# Build the representation
representation = PatternsRepresentation(manager.canonical_activity_representation[:n_patterns],
                                        minicolumns=minicolumns)

training_times_set = [0.050, 0.200]
sigma_number = 40
n_samples_here = n_samples
sigma_max = total_length 
results_collection = {}


for training_times in training_times_set:
    print(training_times)
    # Build the protocol
    protocol = Protocol()
    protocol.simple_protocol(representation, training_times=training_times, 
                             inter_pulse_intervals=inter_pulse_intervals, inter_sequence_interval=inter_sequence_interval, epochs=epochs, resting_time=resting_time)

    # Run the protocol
    timed_input = manager.run_network_protocol_offline(protocol=protocol)

    results_dictionary = run_sigma_sweep(sigma_number, n_samples_here, sigma_max, manager, 
                                                T_persistence=T_persistence)
    for p_root in p_roots:
        aux = find_root(manager, p_root, total_length, n_samples_here, 
                        T_persistence=T_persistence, factor=factor, verbose=False)
        results_dictionary[p_root] = aux
        
        
    results_collection[training_times] = results_dictionary
# Out:
# 0.05
# 0.2
# CPU times: user 41min 43s, sys: 312 ms, total: 41min 43s
# Wall time: 41min 43s

# %%
ax = None
for index, tt in enumerate(training_times_set):
    results_dictionary = results_collection[tt]
    label = str(tt) + ' (s)'
    ax = plot_mean_success_vs_sigma(results_dictionary, n_samples=n_samples, index=index, label=label, ax=ax)
    for p_root in p_roots:
        result, sigma, length = results_dictionary[p_root]
        ax.plot(sigma, result, '*', ms=ms + 20, color='black')


ax.set_title('Training time robustness')
for p_root in p_roots:
    ax.axhline(p_root, ls='--', color='red')

# %% [markdown]
# ## Complete plot

# %% [markdown]
# ### First plot

# %%
save = True
legend = False
bars = False
captions = True
ylim = [0.0, 1.7]
add_zero_axis = False

factor_scale = 1.5
s1 = int(16 * factor_scale)
s2 = int(12 * factor_scale)
fig = plt.figure(figsize=(s1, s2))

# An example
ax1 = fig.add_subplot(321)
for index, tt in enumerate(training_times_set):
    results_dictionary = results_collection[tt]
    label = r'$T_p$ = ' + str(tt) + ' s'
    ax1 = plot_mean_success_vs_sigma(results_dictionary, n_samples=n_samples, index=index + 1, 
                                     label=label, ax=ax1, add_zero_axis=add_zero_axis)
    for p_root in p_roots:
        result, sigma, length = results_dictionary[p_root]
        ax1.plot(sigma, result, '*', ms=ms + 20, color='black')
        ax1.axhline(p_root, ls='--', color=colors[index + 1])
        ax1.axvline(sigma, ls='--', color=colors[index + 1])
        ax1.annotate(r'$\sigma_{50}$', xy=(sigma, 0), xytext=(-0.05, 0.15),
            arrowprops=dict(facecolor='black', shrink=0.05))

if add_zero_axis:
    ax1.set_ylim([-0.1, 1.1]) 

ax1.set_ylim([0.0, 1.1])
# Training time
ax2 = fig.add_subplot(322)
results_dictionary = results_dictionary_tt
ax2 = plot_sigma_estimates(results_dictionary, title=' ', ax=ax2, legend=legend, bars=bars)
ax2.set_ylim(ylim)

# Add the points
for index, tt in enumerate(training_times_set):
    results_dictionary = results_collection[tt]
    for p_root in p_roots:
        result, sigma, length = results_dictionary[p_root]
        ax2.plot(tt, sigma, '*', ms=ms + 30, color=colors[index + 1])

# Inter Pulse Interval
ax3 = fig.add_subplot(323)
results_dictionary = results_dictionary_ipi
ax3 = plot_sigma_estimates(results_dictionary, title=' ', ax=ax3, legend=legend, bars=bars)
ax3.set_ylim(ylim)

# tau_z
ax4 = fig.add_subplot(324)
results_dictionary = results_dictionary_tau_z
ax4.axvline(tau_z_post, ls='--', color='red', label=r'$\tau_{z_{post}}$', lw=lw - 3)
ax4.legend(frameon=False)
ax4 = plot_sigma_estimates(results_dictionary, title=' ', ax=ax4, legend=legend, bars=bars)
ax4.set_ylim(ylim)


# Minicolumns
ax5 = fig.add_subplot(325)
results_dictionary = results_dictionary_minicolumns
ax5 = plot_sigma_estimates(results_dictionary, title=' ', ax=ax5, legend=legend, bars=bars)
ax5.set_ylim(ylim)
ax5.set_xlim([4.0, 31])

xlabels_points = np.arange(5, 35, 5)
xlocations = xlabels_points
xlabels_string = [f'{x}' for x in xlabels_points]
ax5.xaxis.set_major_locator(plt.FixedLocator(xlocations))
ax5.xaxis.set_major_formatter(plt.FixedFormatter(xlabels_string))


# Hypercolumns
ax6 = fig.add_subplot(326)
results_dictionary = results_dictionary_hyper
ax6 = plot_sigma_estimates(results_dictionary, title=' ', ax=ax6, legend=legend, bars=bars)
ax6.set_ylim(ylim)

xlabels_points = np.array([1, 5, 10, 15, 20, 25, 30], dtype='int')
xlocations = xlabels_points
xlabels_string = [f'{x}' for x in xlabels_points]
ax6.xaxis.set_major_locator(plt.FixedLocator(xlocations))
ax6.xaxis.set_major_formatter(plt.FixedFormatter(xlabels_string))


for ax_aux in [ax2, ax3, ax4, ax5, ax6]:
    ylabels_points = [0.0, 0.5, 1.0, 1.5]
    ylocations = ylabels_points
    ylabels_string = [f'{y}' for y in ylabels_points]
    ax_aux.yaxis.set_major_locator(plt.FixedLocator(ylocations))
    ax_aux.yaxis.set_major_formatter(plt.FixedFormatter(ylabels_string))

if captions:
    size = 40
    xpoint1 = 0.05
    xpoint2 = 0.53
    
    ypoint1 = 0.98
    ypoint2 = 0.65
    ypoint3 = 0.34
    
    fig.text(xpoint1, ypoint1, 'A', size=size)
    fig.text(xpoint2, ypoint1, 'B', size=size)
    
    fig.text(xpoint1, ypoint2, 'C', size=size)
    fig.text(xpoint2, ypoint2, 'D', size=size)
    
    fig.text(xpoint1, ypoint3, 'E', size=size)
    fig.text(xpoint2, ypoint3, 'F', size=size)


fig.tight_layout()

if save:
    directory = '../plot_producers/'
    file_name = 'noise_robustness' 
    format_string = '.pdf'
    string_to_save = directory + file_name + format_string
    fig.savefig(string_to_save, frameon=False, dpi=110, bbox_inches='tight')

# %% [markdown]
# ### Reliability plot

# %%
save = True
legend = False
bars = False
captions = True
ylim = [0.0, 2.0]
add_zero_axis = False

factor_scale = 1.5
s1 = int(16 * factor_scale)
s2 = int(12 * factor_scale)
fig = plt.figure(figsize=(s1, s2))

# An example
ax1 = fig.add_subplot(321)
for index, tt in enumerate(training_times_set):
    results_dictionary = results_collection[tt]
    label = r'$T_p$ = ' + str(1000 * tt) + ' ms'
    ax1 = plot_mean_success_vs_sigma(results_dictionary, n_samples=n_samples, index=index + 1, 
                                     label=label, ax=ax1, add_zero_axis=add_zero_axis)
    for p_root in p_roots:
        result, sigma, length = results_dictionary[p_root]
        ax1.plot(sigma, result, '*', ms=ms + 20, color='black')
        ax1.axhline(p_root, ls='--', color=colors[index + 1])
        ax1.axvline(sigma, ls='--', color=colors[index + 1])
        ax1.annotate(r'$p_{50}$', xy=(sigma, p_root), xytext=(-0.05, 0.15),
            arrowprops=dict(facecolor='black', shrink=0.05))


if add_zero_axis:
    ax1.set_ylim([-0.1, 1.1]) 

ax1.set_ylim([0.0, 1.1])
# Training time
ax2 = fig.add_subplot(322)
results_dictionary = results_dictionary_tt
ax2 = plot_p_estimates(results_dictionary, n_samples=n_samples, title=' ', ax=ax2, legend=legend);
ax2.set_ylim(ylim)


# Inter Pulse Interval
ax3 = fig.add_subplot(323)
results_dictionary = results_dictionary_ipi
ax3 = plot_p_estimates(results_dictionary, n_samples=n_samples, title=' ', ax=ax3, legend=legend);
ax3.set_ylim(ylim)

# tau_z
ax4 = fig.add_subplot(324)
results_dictionary = results_dictionary_tau_z
ax4.axvline(tau_z_post, ls='--', color='red', label=r'$\tau_{z_{post}}$', lw=lw)
ax4.legend(frameon=False)
ax4 = plot_p_estimates(results_dictionary, n_samples=n_samples, title=' ', ax=ax4, legend=legend);
ax4.set_ylim(ylim)


# Minicolumns
ax5 = fig.add_subplot(325)
results_dictionary = results_dictionary_minicolumns
ax5 = plot_p_estimates(results_dictionary,n_samples=n_samples, title=' ', ax=ax5, legend=legend);
ax5.set_ylim(ylim)
ax5.set_xlim([4.0, 31])

xlabels_points = np.arange(5, 35, 5)
xlocations = xlabels_points
xlabels_string = [f'{x}' for x in xlabels_points]
ax5.xaxis.set_major_locator(plt.FixedLocator(xlocations))
ax5.xaxis.set_major_formatter(plt.FixedFormatter(xlabels_string))


# Hypercolumns
ax6 = fig.add_subplot(326)
results_dictionary = results_dictionary_hyper
ax6 = plot_p_estimates(results_dictionary, n_samples=n_samples, title=' ', ax=ax6, legend=legend);
ax6.set_ylim(ylim)

xlabels_points = np.array([1, 5, 10, 15, 20, 25, 30], dtype='int')
xlocations = xlabels_points
xlabels_string = [f'{x}' for x in xlabels_points]
ax6.xaxis.set_major_locator(plt.FixedLocator(xlocations))
ax6.xaxis.set_major_formatter(plt.FixedFormatter(xlabels_string))


for ax_aux in [ax2, ax3, ax4, ax5, ax6]:
    ax_aux.axhline(0.5, ls='--', lw=lw, color='gray')
    ax_aux.set_ylim([0.4, 0.6])
    ylabels_points = [0.4, 0.5, 0.6]
    ylocations = ylabels_points
    ylabels_string = [f'{y}' for y in ylabels_points]
    ax_aux.yaxis.set_major_locator(plt.FixedLocator(ylocations))
    ax_aux.yaxis.set_major_formatter(plt.FixedFormatter(ylabels_string))

if captions:
    size = 40
    xpoint1 = 0.05
    xpoint2 = 0.53
    
    ypoint1 = 0.98
    ypoint2 = 0.65
    ypoint3 = 0.34
    
    fig.text(xpoint1, ypoint1, 'A', size=size)
    fig.text(xpoint2, ypoint1, 'B', size=size)
    
    fig.text(xpoint1, ypoint2, 'C', size=size)
    fig.text(xpoint2, ypoint2, 'D', size=size)
    
    fig.text(xpoint1, ypoint3, 'E', size=size)
    fig.text(xpoint2, ypoint3, 'F', size=size)


fig.tight_layout()

if save:
    directory = '../plot_producers/'
    file_name = 'noise_estimates' 
    format_string = '.pdf'
    string_to_save = directory + file_name + format_string
    fig.savefig(string_to_save, frameon=False, dpi=110, bbox_inches='tight')
