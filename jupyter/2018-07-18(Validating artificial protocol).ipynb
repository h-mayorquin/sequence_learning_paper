# %% [markdown]
# # Validating artificial protocol
# We create the connectivity matrix here, this is meant as a functional test for the function

# %%
import  pprint
import  subprocess 
import sys 
sys.path.append('../')

import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
import seaborn as sns

# %matplotlib inline
plt.rcParams['figure.figsize'] = (12.9, 12)

np.set_printoptions(suppress=True, precision=5)

sns.set(font_scale=3.5)

# %%
from connectivity_functions import create_weight_matrix
from activity_representation import create_canonical_activity_representation
from network import Protocol, NetworkManager, Network
from plotting_functions import plot_weight_matrix

# %%
minicolumns = 10
hypercolumns = 2
n_patterns = 10
seq = create_canonical_activity_representation(minicolumns, hypercolumns)[:n_patterns]

ws = 3.0
wn = 2.0
wb = -1.0
alpha = 0.5
extension = 5


w = create_weight_matrix(minicolumns, seq, ws, wn, wb, alpha, extension, w=None)
# Neural Network
nn = Network(hypercolumns, minicolumns)
dt = 0.1
# Build the manager
manager = NetworkManager(nn=nn, dt=dt)
nn.w = w
plot_weight_matrix(manager, one_hypercolum=False)

# %%
minicolumns = 10
hypercolumns = 1
n_patterns = 10
seq = create_canonical_activity_representation(minicolumns, hypercolumns)[:n_patterns]

ws = 3.0
wn = 2.0
wb = -1.0
alpha = 1.5
extension = 25


w = create_weight_matrix(minicolumns, seq, ws, wn, wb, alpha, extension, w=None)
# Neural Network
nn = Network(hypercolumns, minicolumns)
dt = 0.1
# Build the manager
manager = NetworkManager(nn=nn, dt=dt)
nn.w = w
plot_weight_matrix(manager, one_hypercolum=False)

# %%
fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111)
ax.plot(w[:, 5], 'o-', lw=5, ms=12)

ax.axhline(ws, ls='--', label='ws')
ax.axhline(wn, ls='--', label='wn')
ax.axhline(wb, ls='--', label='wb')


ax.legend();
